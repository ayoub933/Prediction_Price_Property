# %%
# !pip install psycopg2-binary
import psycopg2
from psycopg2 import sql
import os
from pathlib import Path

# %%
try:
    connexion = psycopg2.connect(
        host="localhost",
        database="real_estate_db",
        user="lamloum",
        password="lamloum123"
    )
    connexion.autocommit = True
    curseur = connexion.cursor()
    
    curseur.execute("TRUNCATE TABLE properties CASCADE;")
    print("Table properties vidée")

    curseur.close()
    connexion.close()

except Exception as e:
    print(f"Erreur : {e}")
# Out:
# Table properties vidée

# %%
curseur = connexion.cursor()
requête = "SELECT listing_type, COUNT(*) AS n FROM properties GROUP BY 1 ORDER BY n DESC;"
curseur.execute(requête)
resultats = curseur.fetchall()

for ligne in resultats:
    print(ligne)
# Out:
# ('sale', 6814)
# ('rent', 1870)

# %%
curseur = connexion.cursor()
requête = """SELECT count(*) from properties"""
curseur.execute(requête)
resultats = curseur.fetchall()

for ligne in resultats:
    print(ligne)
# Out:
# (8684,)

# %%
# Prix minimum, maximum et moyen
requête = """
TRUNCATE TABLE properties CASCADE;
    """
cursor.execute(requête)

for ligne in resultats:
    print(ligne)

# %%
pip install ydata-profiling --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from connection import get_connection
conn = get_connection()
df = pd.read_sql("SELECT * FROM properties;", conn)
conn.close()
print(df.head())
print(df.info())
print(df.describe())
# Out:
# C:\Users\ghass\AppData\Local\Temp\ipykernel_61380\2976310664.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM properties;", conn)  # mets rent/sale si tu veux
#      id                                              title  \
# 0  7689     200 Gerstmar Road 10, Kelowna, BC, V1X 4A7, CA
# 1  9195  5 St Louis Street 513, St. Albert, AB, T8N 7T2...
# 2  9204        509 2 Avenue W, Drumheller, AB, T0J 0Y3, CA
# 3  9212  30 Meadowglen Place 203, Toronto (Woburn), ON,...
# 4  9220  30 Meadowglen Place 203, Toronto, ON, M1G 0A6, CA
#
#                                              address     price  surface  \
# 0     200 Gerstmar Road 10, Kelowna, BC, V1X 4A7, CA  249000.0   1000.0
# 1  5 St Louis Street 513, St. Albert, AB, T8N 7T2...  460000.0   1233.0
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Profil complet", minimal=True)
profile.to_notebook_iframe()
profile.to_file("rapport_profiling.html")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-08-21 16:01:18.266148&quot;&gt;&lt;title&gt;Profil complet&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
